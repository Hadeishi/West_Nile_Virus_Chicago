# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_df = pd.read_csv('../input/test.csv', index_col = 0)

# %%
train_df = pd.read_csv('../input/train.csv', index_col = 0)

# %%
weather_df = pd.read_csv('../input/weather.csv', index_col = 0)

# %%
spray_df = pd.read_csv('../input/spray.csv', index_col = 0)

# %%
spray_df
# Out:
#                   Time   Latitude  Longitude
# Date
# 2011-08-29  6:56:58 PM  42.391623 -88.089163
# 2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2011-08-29  6:57:18 PM  42.391022 -88.089157
# 2011-08-29  6:57:28 PM  42.390637 -88.089158
# 2011-08-29  6:57:38 PM  42.390410 -88.088858
# 2011-08-29  6:57:48 PM  42.390395 -88.088315
# 2011-08-29  6:57:58 PM  42.390673 -88.088002
# 2011-08-29  6:58:08 PM  42.391027 -88.088002
# 2011-08-29  6:58:18 PM  42.391403 -88.088003
# 2011-08-29  6:58:28 PM  42.391718 -88.087995
# 2011-08-29  6:58:38 PM  42.392038 -88.087988
# 2011-08-29  6:58:48 PM  42.392410 -88.088078
# 2011-08-29  6:58:58 PM  42.392800 -88.088332
# 2011-08-29  6:59:08 PM  42.393257 -88.088370
# 2011-08-29  6:59:18 PM  42.393600 -88.088232
# 2011-08-29  7:00:08 PM  42.393203 -88.088417
# 2011-08-29  7:00:18 PM  42.392792 -88.088312
# 2011-08-29  7:00:28 PM  42.392477 -88.088210
# 2011-08-29  7:00:38 PM  42.392385 -88.088697
# 2011-08-29  7:00:48 PM  42.392098 -88.089113
# ...

# %% [markdown]
# #### Date sprayed from 8/29/2011 - 9/5/2013.  Need to map these spray events, do time series

# %%
spray_df['Time'].describe()
# Out:
# count          14251
# unique          8583
# top       7:44:32 PM
# freq             541
# Name: Time, dtype: object

# %%
weather_df.head()
# Out:
#                Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# Station
# 1        2007-05-01    83    50   67     14        51      56    0    2
# 2        2007-05-01    84    52   68      M        51      57    0    3
# 1        2007-05-02    59    42   51     -3        42      47   14    0
# 2        2007-05-02    60    43   52      M        42      47   13    0
# 1        2007-05-03    66    46   56      2        40      48    9    0
#
#         Sunrise    ...    CodeSum Depth Water1 SnowFall PrecipTotal  \
# Station            ...
# 1          0448    ...                0      M      0.0        0.00
# 2             -    ...                M      M        M        0.00
# 1          0447    ...         BR     0      M      0.0        0.00
# 2             -    ...      BR HZ     M      M        M        0.00
# 1          0446    ...                0      M      0.0        0.00
#
#         StnPressure SeaLevel ResultSpeed  ResultDir  AvgSpeed
# Station
# ...

# %%
train_df
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 2007-05-29     2200 West 113th Street, Chicago, IL 60643, USA
# ...

# %% [markdown]
# #### Mosquito collection from 5/29/2007 - 9/26/2013, years before and during spraying.

# %%
test_df
# Out:
#               Date                                            Address  \
# Id
# 1       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 5       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 6       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 7       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 8       2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 9       2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 10      2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 11      2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 12      2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# ...

# %% [markdown]
# #### test_df dates run from 6/11/2008 - 10/2/2014, different dates from train dates.
#
# #### Aim is to predict WnvPresent, given date, weather, trap location, mosquito species, time since last spray (different types of pesticide?).
#
# #### Plan of attack:
#     1. Get map of mosquito trap locations.  Parallel, look into different species of mosquito as vectors of West Nile (answered; two have been shown WNV+ in this dataset, or "multiple species")
#     2. make time series of mosquito data, by month; compare before and after spraying
#     3. look into location of spraying and effects on mosquitos, and WNV.
#     4. Predict effect of spraying, by comparing effect comparing day of year to day of year (or week of year, anyway...)
#     5. See if weather has significant effect, by
#
# #### Problem:  train dates and test dates differ.  Might be differentially affected by weather
# #### Problem:
