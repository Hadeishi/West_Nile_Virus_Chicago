# %% [markdown]
# # 01A Data Cleansing Weather

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# %matplotlib inline

# %% [markdown]
# ## Read Data

# %%
weather_df = pd.read_csv('../west_nile/west_nile/input/weather.csv')

# %% [markdown]
# ## One Hot Encode CodeSum Data

# %%
codes = {code: [0]*weather_df.shape[0] for codes in weather_df.CodeSum.unique() for code in codes.split()}

weather_df = weather_df.join(pd.DataFrame(codes))
for i, codesum in enumerate(weather_df.CodeSum):
    for code in codesum.split():
        weather_df.at[i, code] = 1
        
codes_df = weather_df.groupby('Date', as_index=True)[list(codes.keys())].max()

# %% [markdown]
# ## Export codes_df

# %%
with open('../Cleansed_Data/codes_df.pkl', 'wb') as f:
    pickle.dump(codes_df, f)

# %% [markdown]
# ----------

# %% [markdown]
# # New Weather Processing

# %% [markdown]
# ## Import weather data

# %%
weather = pd.read_csv('../west_nile/west_nile/input/weather.csv')

# %% [markdown]
# ## Impute missing Tavg Values and Convert column to Int

# %%
missing_Tavg = weather[weather.Tavg == 'M'].index

weather.loc[missing_Tavg, 'Tavg'] = round((weather.loc[missing_Tavg, 'Tmax'] 
                                              + weather.loc[missing_Tavg, 'Tmin'])/2)
weather.Tavg = weather.Tavg.astype(int)

# %% [markdown]
# ## Impute missing AvgSpeed and Convert column to float

# %%
median_wind = weather[weather.AvgSpeed!='M'].AvgSpeed.median()
weather.AvgSpeed.replace('M', median_wind, inplace=True)
weather.AvgSpeed = weather.AvgSpeed.astype(float)

# %% [markdown]
# ## Create Temperature Columns in Celsius

# %%
def celsius(x):
    c = ((x - 32) * 5.0)/9.0
    return float(c)

# %%
weather['TavgC'] = weather['Tavg'].apply(celsius)
weather['TminC'] = weather['Tmin'].apply(celsius)
weather['TmaxC'] = weather['Tmax'].apply(celsius)

# %% [markdown]
# ## Calculate Relative Humidity

# %%
weather['relative_humidity'] = 100 * (np.exp((17.625 * weather.DewPoint.apply(celsius)) / 
                                             (243.04 + weather.DewPoint.apply(celsius))) / 
                                      np.exp((17.625 * weather.Tavg.apply(celsius)) / 
                                             (243.04 + weather.Tavg.apply(celsius))))

# %% [markdown]
# ## Convert DewPoint to Celsius

# %%
weather['DewPointC'] = weather['DewPoint'].apply(celsius)

# %% [markdown]
# ## Add rain boolean

# %% [markdown]
# - TS THUNDERSTORM
# - GR HAIL
# - RA RAIN
# - DZ DRIZZLE
# - SH SHOWER

# %%
def filter_codesum(x):
    for code in rain:
        if code in x:
            return 1
        else:
            return 0

# %%
rain = ['RA', 'DZ', 'SH', 'TS', 'GR']

# %%
weather['rain'] = weather.CodeSum.apply(filter_codesum)

# %% [markdown]
# ## Add Ideal Environment boolean

# %%
weather.loc[(weather['TavgC'] >= 10) & (weather['TavgC'] <= 35) & 
            (weather['relative_humidity'] <= 95) & (weather['relative_humidity'] >= 40) & 
            (weather['AvgSpeed'] <= 6), 
            'ideal_environment']=1

weather.ideal_environment.fillna(0, inplace=True)

# %% [markdown]
# ## Add Ideal Feeding Conditions boolean

# %%
weather.loc[(weather['TavgC'] >= 15) & (weather['TavgC'] <= 30) & 
            (weather['relative_humidity'] >= 8) & (weather['relative_humidity'] <= 72) & 
            (weather['AvgSpeed'] <= 6), 
            'ideal_feeding']=1

weather.ideal_feeding.fillna(0, inplace=True)

# %% [markdown]
# ## Average values to drop station

# %%
new_weather_df = weather.groupby('Date')['TavgC','TmaxC','TminC','DewPointC','relative_humidity',
                                         'rain','ideal_environment','ideal_feeding'].mean()

# %% [markdown]
# ## Calculate Photoperiod

# %%
sun = weather[weather.Station == 1][['Date','Sunset','Sunrise']]

# %%
sun['sundiff'] = sun.apply(lambda x: int(x.Sunset) - int(x.Sunrise), axis=1)

# %%
sun['photoperiod'] =sun.sundiff.map(lambda x: int(str(x)[:2]) + int(str(x)[-2:])/60)

# %%
sun.index = sun.Date

# %%
sun = sun.drop(['Date','Sunset','Sunrise','sundiff'], axis=1)

# %% [markdown]
# ## Join Photoperiod with new_weather_df

# %%
new_weather_df['Date'] = new_weather_df.index

# %%
new_weather_df = new_weather_df.join(sun, on='Date')
# Out:
# /Users/yibingchen/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py:6326: FutureWarning: 'Date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   rsuffix=rsuffix, sort=sort)

# %%
new_weather_df = new_weather_df.drop(['Date'], axis=1)

# %%
new_weather_df.head()
# Out:
#                 TavgC      TmaxC      TminC  DewPointC  relative_humidity  \
# Date
# 2007-05-01  19.722222  28.611111  10.555556  10.555556          55.482501
# 2007-05-02  10.833333  15.277778   5.833333   5.555556          69.905385
# 2007-05-03  13.888889  19.166667   8.333333   4.444444          52.966288
# 2007-05-04  16.111111  22.222222  10.000000   5.277778          48.837189
# 2007-05-05  15.555556  18.888889  11.944444   3.611111          44.842896
#
#             rain  ideal_environment  ideal_feeding  photoperiod
# Date
# 2007-05-01   0.0                0.0            0.0    14.016667
# 2007-05-02   0.0                0.0            0.0    14.050000
# 2007-05-03   0.0                0.0            0.0    14.083333
# 2007-05-04   0.5                0.0            0.0    14.133333
# 2007-05-05   0.0                0.0            0.0    14.166667

# %% [markdown]
# ## Create Weather Features for Last 14 Days

# %%
def time_machine(df, column, days, bc = 0):
    new_df = df[[column]]
    for i in range(1,days+1):
        new_col_name = column + "_" + str(i) +"_back"
        new_col = one_day_back(df, column, i, bc)
        new_df[new_col_name] = new_col
    new_df.drop(column, 1, inplace=True)
    df = df.join(new_df)
    return df

def one_day_back(df, column, day, bc):
    col = df[column].tolist()
    for i in range(day):
        del col[-1]
        col.insert(0, bc)
    return col

# %%
new_weather_df.columns
# Out:
# Index(['TavgC', 'TmaxC', 'TminC', 'DewPointC', 'relative_humidity', 'rain',
#        'ideal_environment', 'ideal_feeding', 'photoperiod'],
#       dtype='object')

# %%
with open('../Cleansed_Data/weather_df_comp.pkl', 'wb') as f:
    pickle.dump(new_weather_df, f)

# %%
time_machine(new_weather_df, 'DewPointC', 14)
# Out:
# /Users/yibingchen/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                 TavgC      TmaxC      TminC  DewPointC  relative_humidity  \
# Date
# 2007-05-01  19.722222  28.611111  10.555556  10.555556          55.482501
# 2007-05-02  10.833333  15.277778   5.833333   5.555556          69.905385
# 2007-05-03  13.888889  19.166667   8.333333   4.444444          52.966288
# 2007-05-04  16.111111  22.222222  10.000000   5.277778          48.837189
# 2007-05-05  15.555556  18.888889  11.944444   3.611111          44.842896
# 2007-05-06  15.277778  20.000000  10.277778  -1.111111          32.524713
# 2007-05-07  18.888889  28.611111   9.166667   4.444444          38.604051
# 2007-05-08  20.555556  27.222222  13.888889  14.166667          66.882020
# 2007-05-09  20.833333  24.722222  16.666667  15.277778          70.530226
# 2007-05-10  21.388889  28.611111  14.166667  11.111111          51.947650
# 2007-05-11  16.111111  21.944444  10.000000   6.111111          51.541931
# 2007-05-12  13.055556  18.055556   8.055556   2.500000          48.721051
# 2007-05-13  13.611111  20.555556   6.388889   0.277778          40.096947
# 2007-05-14  22.500000  32.222222  12.777778   7.777778          38.801155
# 2007-05-15  20.555556  27.222222  13.611111  13.333333          63.268000
# 2007-05-16  12.777778  18.333333   6.944444   5.833333          62.683505
# 2007-05-17  11.666667  16.388889   6.388889   0.000000          44.606027
# 2007-05-18  13.888889  21.388889   5.833333  -0.833333          36.304869
# 2007-05-19  20.000000  26.666667  13.333333   3.333333          33.255129
# 2007-05-20  13.611111  20.555556   6.388889   4.722222          54.947418
# 2007-05-21  16.944444  26.388889   7.222222  10.000000          63.635251
# 2007-05-22  22.500000  30.555556  14.166667   7.222222          37.501489
# 2007-05-23  24.722222  31.666667  17.222222   9.166667          37.372879
# 2007-05-24  24.722222  31.111111  18.055556  11.944444          44.884819
# 2007-05-25  16.944444  20.000000  13.611111   7.222222          52.803432
# 2007-05-26  14.722222  19.722222   9.722222  12.777778          88.276347
# 2007-05-27  19.166667  23.888889  14.444444   8.888889          51.358671
# 2007-05-28  18.333333  25.277778  11.111111   8.888889          54.130642
# 2007-05-29  24.166667  31.111111  16.944444  14.722222          55.614546
# 2007-05-30  25.833333  31.111111  20.000000  14.166667          48.663448
# ...               ...        ...        ...        ...                ...
# 2014-10-02  20.833333  23.055556  18.055556  16.666667          77.087315
# 2014-10-03  13.055556  19.166667   6.944444   7.777778          70.346834
# 2014-10-04   5.555556   8.888889   2.222222   1.388889          74.565315
# 2014-10-05   8.611111  13.055556   4.166667   1.944444          62.978382
# 2014-10-06  12.222222  16.666667   7.222222   3.888889          56.806565
# 2014-10-07  14.444444  19.722222   9.166667   6.666667          59.560020
# 2014-10-08  13.611111  18.888889   7.777778   1.944444          45.199599
# 2014-10-09  12.777778  17.222222   8.055556   1.666667          46.788379
# 2014-10-10  10.277778  14.722222   5.277778   4.166667          65.888299
# 2014-10-11   9.444444  15.277778   3.333333   1.666667          58.318837
# 2014-10-12  11.666667  17.500000   5.277778   6.111111          68.787234
# 2014-10-13  17.500000  20.555556  14.166667  15.277778          86.810568
# 2014-10-14  15.555556  18.888889  11.666667  14.444444          93.101282
# 2014-10-15  12.500000  13.611111  10.833333  11.111111          91.269879
# 2014-10-16  12.500000  13.888889  10.833333  10.277778          86.324573
# 2014-10-17  13.055556  16.944444   9.166667   8.333333          73.045197
# 2014-10-18   6.944444  10.555556   3.055556   3.888889          80.914998
# 2014-10-19   7.500000  13.055556   1.388889   3.888889          77.897731
# 2014-10-20  13.888889  18.611111   8.888889   7.222222          64.138093
# 2014-10-21  10.277778  11.944444   8.333333   4.444444          67.143465
# 2014-10-22   8.888889  13.333333   3.888889   3.333333          68.367726
# 2014-10-23  10.000000  15.833333   3.611111   4.722222          69.851901
# 2014-10-24  15.833333  19.722222  11.666667   8.333333          61.044666
# 2014-10-25  16.944444  23.055556  10.277778   4.722222          44.393514
# 2014-10-26  12.222222  18.333333   6.111111   0.277778          43.885296
# 2014-10-27  18.611111  25.555556  11.388889  10.833333          60.601721
# 2014-10-28  13.888889  19.444444   8.055556   3.888889          50.940587
# 2014-10-29   6.666667   9.444444   3.333333   0.555556          65.027471
# 2014-10-30   6.388889  11.111111   1.388889   1.388889          70.438585
# 2014-10-31   5.000000   8.888889   0.833333  -2.777778          57.212782
#
#             rain  ideal_environment  ideal_feeding  photoperiod  \
# Date
# 2007-05-01   0.0                0.0            0.0    14.016667
# 2007-05-02   0.0                0.0            0.0    14.050000
# 2007-05-03   0.0                0.0            0.0    14.083333
# 2007-05-04   0.5                0.0            0.0    14.133333
# 2007-05-05   0.0                0.0            0.0    14.166667
# 2007-05-06   0.0                0.0            0.0    14.216667
# 2007-05-07   0.5                0.0            0.0    14.250000
# 2007-05-08   0.0                1.0            1.0    14.300000
# 2007-05-09   0.0                0.5            0.5    14.333333
# 2007-05-10   0.0                1.0            1.0    14.366667
# 2007-05-11   0.0                0.0            0.0    14.400000
# 2007-05-12   0.0                0.0            0.0    15.100000
# 2007-05-13   0.0                0.0            0.0    15.133333
# 2007-05-14   0.0                0.0            0.0    15.166667
# 2007-05-15   1.0                0.0            0.0    15.200000
# 2007-05-16   1.0                0.0            0.0    15.233333
# 2007-05-17   0.0                0.0            0.0    15.266667
# 2007-05-18   0.0                0.0            0.0    15.300000
# 2007-05-19   0.0                0.0            0.0    15.333333
# 2007-05-20   1.0                0.0            0.0    15.366667
# 2007-05-21   0.0                0.0            0.0    15.400000
# 2007-05-22   0.0                0.0            0.0    15.433333
# 2007-05-23   0.0                0.0            0.0    15.450000
# 2007-05-24   1.0                0.0            0.0    15.483333
# 2007-05-25   0.5                0.0            0.0    15.516667
# 2007-05-26   1.0                0.0            0.0    15.550000
# 2007-05-27   1.0                0.0            0.0    15.566667
# 2007-05-28   0.5                1.0            1.0    15.583333
# 2007-05-29   0.0                0.0            0.0    15.600000
# 2007-05-30   0.0                0.0            0.0    15.633333
# ...          ...                ...            ...          ...
# 2014-10-02   1.0                0.0            0.0    12.383333
# 2014-10-03   1.0                0.0            0.0    12.333333
# 2014-10-04   1.0                0.0            0.0    12.283333
# 2014-10-05   1.0                0.0            0.0    12.233333
# 2014-10-06   0.0                0.0            0.0    12.183333
# 2014-10-07   0.0                0.0            0.0    12.150000
# 2014-10-08   0.0                0.0            0.0    12.100000
# 2014-10-09   0.0                0.5            0.0    12.050000
# 2014-10-10   0.0                0.5            0.0    12.016667
# 2014-10-11   0.0                0.5            0.0    11.966667
# 2014-10-12   1.0                0.0            0.0    11.250000
# 2014-10-13   1.0                0.0            0.0    11.200000
# 2014-10-14   1.0                0.0            0.0    11.150000
# 2014-10-15   1.0                0.0            0.0    11.116667
# 2014-10-16   0.0                0.0            0.0    11.066667
# 2014-10-17   0.0                0.0            0.0    11.016667
# 2014-10-18   1.0                0.0            0.0    11.650000
# 2014-10-19   0.0                0.0            0.0    11.600000
# 2014-10-20   0.0                0.0            0.0    11.550000
# 2014-10-21   0.0                0.0            0.0    11.500000
# 2014-10-22   0.0                0.5            0.0    10.800000
# 2014-10-23   0.0                0.0            0.0    10.750000
# 2014-10-24   0.0                1.0            1.0    10.716667
# 2014-10-25   0.0                0.0            0.0    10.666667
# 2014-10-26   0.0                1.0            0.0    10.616667
# 2014-10-27   0.5                0.0            0.0    10.583333
# 2014-10-28   0.5                0.0            0.0    10.533333
# 2014-10-29   0.0                0.0            0.0    10.500000
# 2014-10-30   0.5                0.0            0.0    10.450000
# 2014-10-31   1.0                0.0            0.0    10.400000
#
#             DewPointC_1_back        ...          DewPointC_5_back  \
# Date                                ...
# 2007-05-01          0.000000        ...                  0.000000
# 2007-05-02         10.555556        ...                  0.000000
# 2007-05-03          5.555556        ...                  0.000000
# 2007-05-04          4.444444        ...                  0.000000
# 2007-05-05          5.277778        ...                  0.000000
# 2007-05-06          3.611111        ...                 10.555556
# 2007-05-07         -1.111111        ...                  5.555556
# 2007-05-08          4.444444        ...                  4.444444
# 2007-05-09         14.166667        ...                  5.277778
# 2007-05-10         15.277778        ...                  3.611111
# 2007-05-11         11.111111        ...                 -1.111111
# 2007-05-12          6.111111        ...                  4.444444
# 2007-05-13          2.500000        ...                 14.166667
# 2007-05-14          0.277778        ...                 15.277778
# 2007-05-15          7.777778        ...                 11.111111
# 2007-05-16         13.333333        ...                  6.111111
# 2007-05-17          5.833333        ...                  2.500000
# 2007-05-18          0.000000        ...                  0.277778
# 2007-05-19         -0.833333        ...                  7.777778
# 2007-05-20          3.333333        ...                 13.333333
# 2007-05-21          4.722222        ...                  5.833333
# 2007-05-22         10.000000        ...                  0.000000
# 2007-05-23          7.222222        ...                 -0.833333
# 2007-05-24          9.166667        ...                  3.333333
# 2007-05-25         11.944444        ...                  4.722222
# 2007-05-26          7.222222        ...                 10.000000
# 2007-05-27         12.777778        ...                  7.222222
# 2007-05-28          8.888889        ...                  9.166667
# 2007-05-29          8.888889        ...                 11.944444
# 2007-05-30         14.722222        ...                  7.222222
# ...                      ...        ...                       ...
# 2014-10-02         10.277778        ...                 13.055556
# 2014-10-03         16.666667        ...                 13.333333
# 2014-10-04          7.777778        ...                 13.055556
# 2014-10-05          1.388889        ...                  8.888889
# 2014-10-06          1.944444        ...                 10.277778
# 2014-10-07          3.888889        ...                 16.666667
# 2014-10-08          6.666667        ...                  7.777778
# 2014-10-09          1.944444        ...                  1.388889
# 2014-10-10          1.666667        ...                  1.944444
# 2014-10-11          4.166667        ...                  3.888889
# 2014-10-12          1.666667        ...                  6.666667
# 2014-10-13          6.111111        ...                  1.944444
# 2014-10-14         15.277778        ...                  1.666667
# 2014-10-15         14.444444        ...                  4.166667
# 2014-10-16         11.111111        ...                  1.666667
# 2014-10-17         10.277778        ...                  6.111111
# 2014-10-18          8.333333        ...                 15.277778
# 2014-10-19          3.888889        ...                 14.444444
# 2014-10-20          3.888889        ...                 11.111111
# 2014-10-21          7.222222        ...                 10.277778
# 2014-10-22          4.444444        ...                  8.333333
# 2014-10-23          3.333333        ...                  3.888889
# 2014-10-24          4.722222        ...                  3.888889
# 2014-10-25          8.333333        ...                  7.222222
# 2014-10-26          4.722222        ...                  4.444444
# 2014-10-27          0.277778        ...                  3.333333
# 2014-10-28         10.833333        ...                  4.722222
# 2014-10-29          3.888889        ...                  8.333333
# 2014-10-30          0.555556        ...                  4.722222
# 2014-10-31          1.388889        ...                  0.277778
#
#             DewPointC_6_back  DewPointC_7_back  DewPointC_8_back  \
# Date
# 2007-05-01          0.000000          0.000000          0.000000
# 2007-05-02          0.000000          0.000000          0.000000
# 2007-05-03          0.000000          0.000000          0.000000
# 2007-05-04          0.000000          0.000000          0.000000
# 2007-05-05          0.000000          0.000000          0.000000
# 2007-05-06          0.000000          0.000000          0.000000
# 2007-05-07         10.555556          0.000000          0.000000
# 2007-05-08          5.555556         10.555556          0.000000
# 2007-05-09          4.444444          5.555556         10.555556
# 2007-05-10          5.277778          4.444444          5.555556
# 2007-05-11          3.611111          5.277778          4.444444
# 2007-05-12         -1.111111          3.611111          5.277778
# 2007-05-13          4.444444         -1.111111          3.611111
# 2007-05-14         14.166667          4.444444         -1.111111
# 2007-05-15         15.277778         14.166667          4.444444
# 2007-05-16         11.111111         15.277778         14.166667
# 2007-05-17          6.111111         11.111111         15.277778
# 2007-05-18          2.500000          6.111111         11.111111
# 2007-05-19          0.277778          2.500000          6.111111
# 2007-05-20          7.777778          0.277778          2.500000
# 2007-05-21         13.333333          7.777778          0.277778
# 2007-05-22          5.833333         13.333333          7.777778
# 2007-05-23          0.000000          5.833333         13.333333
# 2007-05-24         -0.833333          0.000000          5.833333
# 2007-05-25          3.333333         -0.833333          0.000000
# 2007-05-26          4.722222          3.333333         -0.833333
# 2007-05-27         10.000000          4.722222          3.333333
# 2007-05-28          7.222222         10.000000          4.722222
# 2007-05-29          9.166667          7.222222         10.000000
# 2007-05-30         11.944444          9.166667          7.222222
# ...                      ...               ...               ...
# 2014-10-02         12.222222         11.666667          9.722222
# 2014-10-03         13.055556         12.222222         11.666667
# 2014-10-04         13.333333         13.055556         12.222222
# 2014-10-05         13.055556         13.333333         13.055556
# 2014-10-06          8.888889         13.055556         13.333333
# 2014-10-07         10.277778          8.888889         13.055556
# 2014-10-08         16.666667         10.277778          8.888889
# 2014-10-09          7.777778         16.666667         10.277778
# 2014-10-10          1.388889          7.777778         16.666667
# 2014-10-11          1.944444          1.388889          7.777778
# 2014-10-12          3.888889          1.944444          1.388889
# 2014-10-13          6.666667          3.888889          1.944444
# 2014-10-14          1.944444          6.666667          3.888889
# 2014-10-15          1.666667          1.944444          6.666667
# 2014-10-16          4.166667          1.666667          1.944444
# 2014-10-17          1.666667          4.166667          1.666667
# 2014-10-18          6.111111          1.666667          4.166667
# 2014-10-19         15.277778          6.111111          1.666667
# 2014-10-20         14.444444         15.277778          6.111111
# 2014-10-21         11.111111         14.444444         15.277778
# 2014-10-22         10.277778         11.111111         14.444444
# 2014-10-23          8.333333         10.277778         11.111111
# 2014-10-24          3.888889          8.333333         10.277778
# 2014-10-25          3.888889          3.888889          8.333333
# 2014-10-26          7.222222          3.888889          3.888889
# 2014-10-27          4.444444          7.222222          3.888889
# 2014-10-28          3.333333          4.444444          7.222222
# 2014-10-29          4.722222          3.333333          4.444444
# 2014-10-30          8.333333          4.722222          3.333333
# 2014-10-31          4.722222          8.333333          4.722222
#
#             DewPointC_9_back  DewPointC_10_back  DewPointC_11_back  \
# Date
# 2007-05-01          0.000000           0.000000           0.000000
# 2007-05-02          0.000000           0.000000           0.000000
# 2007-05-03          0.000000           0.000000           0.000000
# 2007-05-04          0.000000           0.000000           0.000000
# 2007-05-05          0.000000           0.000000           0.000000
# 2007-05-06          0.000000           0.000000           0.000000
# 2007-05-07          0.000000           0.000000           0.000000
# 2007-05-08          0.000000           0.000000           0.000000
# 2007-05-09          0.000000           0.000000           0.000000
# 2007-05-10         10.555556           0.000000           0.000000
# 2007-05-11          5.555556          10.555556           0.000000
# 2007-05-12          4.444444           5.555556          10.555556
# 2007-05-13          5.277778           4.444444           5.555556
# 2007-05-14          3.611111           5.277778           4.444444
# 2007-05-15         -1.111111           3.611111           5.277778
# 2007-05-16          4.444444          -1.111111           3.611111
# 2007-05-17         14.166667           4.444444          -1.111111
# 2007-05-18         15.277778          14.166667           4.444444
# 2007-05-19         11.111111          15.277778          14.166667
# 2007-05-20          6.111111          11.111111          15.277778
# 2007-05-21          2.500000           6.111111          11.111111
# 2007-05-22          0.277778           2.500000           6.111111
# 2007-05-23          7.777778           0.277778           2.500000
# 2007-05-24         13.333333           7.777778           0.277778
# 2007-05-25          5.833333          13.333333           7.777778
# 2007-05-26          0.000000           5.833333          13.333333
# 2007-05-27         -0.833333           0.000000           5.833333
# 2007-05-28          3.333333          -0.833333           0.000000
# 2007-05-29          4.722222           3.333333          -0.833333
# 2007-05-30         10.000000           4.722222           3.333333
# ...                      ...                ...                ...
# 2014-10-02          8.333333           6.666667          10.277778
# 2014-10-03          9.722222           8.333333           6.666667
# 2014-10-04         11.666667           9.722222           8.333333
# 2014-10-05         12.222222          11.666667           9.722222
# 2014-10-06         13.055556          12.222222          11.666667
# 2014-10-07         13.333333          13.055556          12.222222
# 2014-10-08         13.055556          13.333333          13.055556
# 2014-10-09          8.888889          13.055556          13.333333
# 2014-10-10         10.277778           8.888889          13.055556
# 2014-10-11         16.666667          10.277778           8.888889
# 2014-10-12          7.777778          16.666667          10.277778
# 2014-10-13          1.388889           7.777778          16.666667
# 2014-10-14          1.944444           1.388889           7.777778
# 2014-10-15          3.888889           1.944444           1.388889
# 2014-10-16          6.666667           3.888889           1.944444
# 2014-10-17          1.944444           6.666667           3.888889
# 2014-10-18          1.666667           1.944444           6.666667
# 2014-10-19          4.166667           1.666667           1.944444
# 2014-10-20          1.666667           4.166667           1.666667
# 2014-10-21          6.111111           1.666667           4.166667
# 2014-10-22         15.277778           6.111111           1.666667
# 2014-10-23         14.444444          15.277778           6.111111
# 2014-10-24         11.111111          14.444444          15.277778
# 2014-10-25         10.277778          11.111111          14.444444
# 2014-10-26          8.333333          10.277778          11.111111
# 2014-10-27          3.888889           8.333333          10.277778
# 2014-10-28          3.888889           3.888889           8.333333
# 2014-10-29          7.222222           3.888889           3.888889
# 2014-10-30          4.444444           7.222222           3.888889
# 2014-10-31          3.333333           4.444444           7.222222
#
#             DewPointC_12_back  DewPointC_13_back  DewPointC_14_back
# Date
# 2007-05-01           0.000000           0.000000           0.000000
# 2007-05-02           0.000000           0.000000           0.000000
# 2007-05-03           0.000000           0.000000           0.000000
# 2007-05-04           0.000000           0.000000           0.000000
# 2007-05-05           0.000000           0.000000           0.000000
# 2007-05-06           0.000000           0.000000           0.000000
# 2007-05-07           0.000000           0.000000           0.000000
# 2007-05-08           0.000000           0.000000           0.000000
# 2007-05-09           0.000000           0.000000           0.000000
# 2007-05-10           0.000000           0.000000           0.000000
# 2007-05-11           0.000000           0.000000           0.000000
# 2007-05-12           0.000000           0.000000           0.000000
# 2007-05-13          10.555556           0.000000           0.000000
# 2007-05-14           5.555556          10.555556           0.000000
# 2007-05-15           4.444444           5.555556          10.555556
# 2007-05-16           5.277778           4.444444           5.555556
# 2007-05-17           3.611111           5.277778           4.444444
# 2007-05-18          -1.111111           3.611111           5.277778
# 2007-05-19           4.444444          -1.111111           3.611111
# 2007-05-20          14.166667           4.444444          -1.111111
# 2007-05-21          15.277778          14.166667           4.444444
# 2007-05-22          11.111111          15.277778          14.166667
# 2007-05-23           6.111111          11.111111          15.277778
# 2007-05-24           2.500000           6.111111          11.111111
# 2007-05-25           0.277778           2.500000           6.111111
# 2007-05-26           7.777778           0.277778           2.500000
# 2007-05-27          13.333333           7.777778           0.277778
# 2007-05-28           5.833333          13.333333           7.777778
# 2007-05-29           0.000000           5.833333          13.333333
# 2007-05-30          -0.833333           0.000000           5.833333
# ...                       ...                ...                ...
# 2014-10-02          16.388889           9.166667          11.666667
# 2014-10-03          10.277778          16.388889           9.166667
# 2014-10-04           6.666667          10.277778          16.388889
# 2014-10-05           8.333333           6.666667          10.277778
# 2014-10-06           9.722222           8.333333           6.666667
# 2014-10-07          11.666667           9.722222           8.333333
# 2014-10-08          12.222222          11.666667           9.722222
# 2014-10-09          13.055556          12.222222          11.666667
# 2014-10-10          13.333333          13.055556          12.222222
# 2014-10-11          13.055556          13.333333          13.055556
# 2014-10-12           8.888889          13.055556          13.333333
# 2014-10-13          10.277778           8.888889          13.055556
# 2014-10-14          16.666667          10.277778           8.888889
# 2014-10-15           7.777778          16.666667          10.277778
# 2014-10-16           1.388889           7.777778          16.666667
# 2014-10-17           1.944444           1.388889           7.777778
# 2014-10-18           3.888889           1.944444           1.388889
# 2014-10-19           6.666667           3.888889           1.944444
# 2014-10-20           1.944444           6.666667           3.888889
# 2014-10-21           1.666667           1.944444           6.666667
# 2014-10-22           4.166667           1.666667           1.944444
# 2014-10-23           1.666667           4.166667           1.666667
# 2014-10-24           6.111111           1.666667           4.166667
# 2014-10-25          15.277778           6.111111           1.666667
# 2014-10-26          14.444444          15.277778           6.111111
# 2014-10-27          11.111111          14.444444          15.277778
# 2014-10-28          10.277778          11.111111          14.444444
# 2014-10-29           8.333333          10.277778          11.111111
# 2014-10-30           3.888889           8.333333          10.277778
# 2014-10-31           3.888889           3.888889           8.333333
#
# [1472 rows x 23 columns]

# %%
for col in new_weather_df.columns:
    new_weather_df = time_machine(new_weather_df, col, 14)
# Out:
# /Users/yibingchen/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/yibingchen/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Export new_weather_df

# %%
with open('../Cleansed_Data/new_weather_df.pkl', 'wb') as f:
    pickle.dump(new_weather_df, f)
